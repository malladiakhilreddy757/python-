# %% [markdown]
# # Pandas Introduction:
#
# # What is Pandas?
#
# . Pandas is a Python library used for working with data sets.
#
# . It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# ##### The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes            McKinney in 2008.
#
# # Why Use Pandas?
#
# . Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# . Pandas can clean messy data sets, and make them readable and relevant.
#
# . Relevant data is very important in data science.
#
# ##### NOTE:
#             Data Science: is a branch of computer science where we study how to store, use and analyze             data  for deriving information from it.
#
# # What Can Pandas Do?
#
# . Pandas gives you answers about the data. Like:
#
# . Is there a correlation between two or more columns?
#
# ##### What is average value?
#
# ##### Max value?
#
# ##### Min value?
#
# . Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or     NULL values. This is called cleaning the data.

# %% [markdown]
# # Pandas
# . Pandas is an open-source Python Library providing high-performance data manipulation and analysis .
#
# . tool using its powerful data structures.
#
# . Using Pandas, we can accomplish five typical steps in the processing and analysis of data,             regardless of the origin of data — load, prepare, manipulate, model, and analyze.
#
# ##### Pandas deals with the following three data structures
#
# ##### 1) Series
#
# ##### 2) DataFrame
#
# ##### 3) Panel
#
# # 1) Series
# Series is a one-dimensional array like structure with homogeneous data.
#
# #### Creating Series
#
# A series can be created using various inputs like −
#
#     1) Array.
#
#     2) Dict.
#
#     3) Scalar value or constant
#
# installing pandas

# %%
# !pip install pandas

# %%
import pandas# to use the pandas we need to import it first

# %%
print(pandas.__version__)
# Out:
# 1.3.4

# %%
import pandas as pd # alliese name to become easy

# %%
d =pd.read_excel("C:\\Users\\user\\Downloads\\student marks.xlsx")
df=pd.DataFrame(d)

# %%
df
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 0      AKHIL        1       10TH      90     89       86     99        95
# 1       ANIL        2       10TH      91     78       45     78        78
# 2      SUNNY        3       10TH      92     90       66     78        89
# 3     VISHWA        4       10TH      93     90       77     89        45
# 4     VAMSHI        5       10TH      97     98       87     88        56
# 5      SHIVA        6       10TH      85     77       98     56        67
# 6   SRINIVAS        7       10TH      86     55       90     76        89
# 7        RAJ        8       10TH      83     87       35     87        45
# 8       RAVI        9       10TH      90     55       56     54        66
# 9    PRAMODH       10       10TH      97     54       56     35        78
# 10    SHASHI       11       10TH      98     65       77     33        98
# 11       RAM       12       10TH      99     34       98     78        90
# ...

# %%
di={"name" :["akhil","anil","sunny"],"Roll_no" : [1,2,3],"marks" : [85,95,99]}

# %%
di
# Out:
# {'name': ['akhil', 'anil', 'sunny'],
#  'Roll_no': [1, 2, 3],
#  'marks': [85, 95, 99]}

# %%
df=pd.DataFrame(di)

# %%
df
# Out:
#     name  Roll_no  marks
# 0  akhil        1     85
# 1   anil        2     95
# 2  sunny        3     99

# %%
l=[("name", 23,24,25),("Roll_no", 1,2,3),("marks",85,95,99)]

# %%
l
# Out:
# [('name', 23, 24, 25), ('Roll_no', 1, 2, 3), ('marks', 85, 95, 99)]

# %%
df=pd.DataFrame(l)

# %%
df
# Out:
#          0   1   2   3
# 0     name  23  24  25
# 1  Roll_no   1   2   3
# 2    marks  85  95  99

# %%
d =pd.read_excel("C:\\Users\\user\\Downloads\\student marks.xlsx")
df=pd.DataFrame(d)

# %%
df
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 0      AKHIL        1       10TH      90     89       86     99        95
# 1       ANIL        2       10TH      91     78       45     78        78
# 2      SUNNY        3       10TH      92     90       66     78        89
# 3     VISHWA        4       10TH      93     90       77     89        45
# 4     VAMSHI        5       10TH      97     98       87     88        56
# 5      SHIVA        6       10TH      85     77       98     56        67
# 6   SRINIVAS        7       10TH      86     55       90     76        89
# 7        RAJ        8       10TH      83     87       35     87        45
# 8       RAVI        9       10TH      90     55       56     54        66
# 9    PRAMODH       10       10TH      97     54       56     35        78
# 10    SHASHI       11       10TH      98     65       77     33        98
# 11       RAM       12       10TH      99     34       98     78        90
# ...

# %% [markdown]
# # Indexing slicing

# %% [markdown]
# ![pd3.jfif](attachment:pd3.jfif)

# %%
df.head()# here by defalt the first 5 records will be displayed from the top
# Out:
#      NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   SOCIAL
# 0   AKHIL        1       10TH      90     89       86     99        95      92
# 1    ANIL        2       10TH      91     78       45     78        78      56
# 2   SUNNY        3       10TH      92     90       66     78        89      67
# 3  VISHWA        4       10TH      93     90       77     89        45      37
# 4  VAMSHI        5       10TH      97     98       87     88        56      87

# %%
df.head(3)# here the first 3 records will be displayed from the top
# Out:
#     NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   SOCIAL
# 0  AKHIL        1       10TH      90     89       86     99        95      92
# 1   ANIL        2       10TH      91     78       45     78        78      56
# 2  SUNNY        3       10TH      92     90       66     78        89      67

# %%
df.tail()# here by defalt  last 5 records will be displayed .
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 14      RAJI       15      10TH       76     45       45     66        98
# 15      AJAY       16      10TH       78     77       90     56        56
# 16     VIJAY       17      10TH       78     89       89     78        47
# 17    BABBLU       18      10TH       89     56       77     35        74
# 18  SAIKUMAR       19      10TH       53     55       54     77        78
#
#     SOCIAL
# 14      34
# 15      33
# 16      88
# 17      78
# 18      70

# %%
df.tail(3)# here last 3 records will be displayed
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 16     VIJAY       17      10TH       78     89       89     78        47
# 17    BABBLU       18      10TH       89     56       77     35        74
# 18  SAIKUMAR       19      10TH       53     55       54     77        78
#
#     SOCIAL
# 16      88
# 17      78
# 18      70

# %%
df.describe()
# Out:
#          ROLL NO     TELUGU      HINDI    ENGLISH      MATHS   SCIENCE   \
# count  19.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean   10.000000  85.263158  67.000000  68.631579  70.368421  75.105263
# std     5.627314  12.909265  20.520992  21.754209  20.353025  18.174753
# min     1.000000  53.000000  34.000000  33.000000  33.000000  45.000000
# 25%     5.500000  80.500000  54.500000  49.500000  56.000000  61.000000
# 50%    10.000000  90.000000  65.000000  77.000000  77.000000  78.000000
# 75%    14.500000  92.500000  88.000000  88.000000  82.500000  89.000000
# max    19.000000  99.000000  98.000000  98.000000  99.000000  98.000000
#
#           SOCIAL
# count  19.000000
# mean   67.684211
# std    24.417782
# min    33.000000
# 25%    41.500000
# 50%    70.000000
# 75%    88.500000
# max    99.000000

# %%
df.shape# it gives the no of rows and coloums
# Out:
# (19, 9)

# %%
df[0:9]
# Out:
#        NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 0     AKHIL        1       10TH      90     89       86     99        95
# 1      ANIL        2       10TH      91     78       45     78        78
# 2     SUNNY        3       10TH      92     90       66     78        89
# 3    VISHWA        4       10TH      93     90       77     89        45
# 4    VAMSHI        5       10TH      97     98       87     88        56
# 5     SHIVA        6       10TH      85     77       98     56        67
# 6  SRINIVAS        7       10TH      86     55       90     76        89
# 7       RAJ        8       10TH      83     87       35     87        45
# 8      RAVI        9       10TH      90     55       56     54        66
#
#    SOCIAL
# 0      92
# 1      56
# 2      67
# 3      37
# 4      87
# 5      88
# 6      89
# 7      99
# 8      89

# %%
df["NAME"]#GETTING the coloum by using the coloum name
# Out:
# 0        AKHIL
# 1         ANIL
# 2        SUNNY
# 3       VISHWA
# 4       VAMSHI
# 5        SHIVA
# 6     SRINIVAS
# 7          RAJ
# 8         RAVI
# 9      PRAMODH
# 10      SHASHI
# 11         RAM
# 12      ROHITH
# 13       RAHUL
# 14        RAJI
# 15        AJAY
# 16       VIJAY
# 17      BABBLU
# 18    SAIKUMAR
# Name: NAME, dtype: object

# %%
df[["NAME","ROLL NO"]]
# Out:
#         NAME  ROLL NO
# 0      AKHIL        1
# 1       ANIL        2
# 2      SUNNY        3
# 3     VISHWA        4
# 4     VAMSHI        5
# 5      SHIVA        6
# 6   SRINIVAS        7
# 7        RAJ        8
# 8       RAVI        9
# 9    PRAMODH       10
# 10    SHASHI       11
# 11       RAM       12
# 12    ROHITH       13
# 13     RAHUL       14
# 14      RAJI       15
# 15      AJAY       16
# 16     VIJAY       17
# 17    BABBLU       18
# 18  SAIKUMAR       19

# %%
df[["NAME","TELUGU"]][0:10:2]
# Out:
#        NAME  TELUGU
# 0     AKHIL      90
# 2     SUNNY      92
# 4    VAMSHI      97
# 6  SRINIVAS      86
# 8      RAVI      90

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, NAME          AKHIL
# ROLL NO           1
# Unnamed: 2     10TH
# TELUGU           90
# HINDI            89
# ENGLISH          86
# MATHS            99
# SCIENCE          95
# SOCIAL           92
# Name: 0, dtype: object)
# (1, NAME          ANIL
# ROLL NO          2
# Unnamed: 2    10TH
# TELUGU          91
# HINDI           78
# ENGLISH         45
# MATHS           78
# SCIENCE         78
# SOCIAL          56
# Name: 1, dtype: object)
# (2, NAME          SUNNY
# ROLL NO           3
# Unnamed: 2     10TH
# TELUGU           92
# HINDI            90
# ENGLISH          66
# MATHS            78
# SCIENCE          89
# SOCIAL           67
# Name: 2, dtype: object)
# (3, NAME          VISHWA
# ROLL NO            4
# Unnamed: 2      10TH
# TELUGU            93
# HINDI             90
# ENGLISH           77
# MATHS             89
# SCIENCE           45
# SOCIAL            37
# Name: 3, dtype: object)
# (4, NAME          VAMSHI
# ROLL NO            5
# Unnamed: 2      10TH
# ...

# %% [markdown]
# ![pd4.jfif](attachment:pd4.jfif)

# %% [markdown]
# in loc[] stop index will be included and rows will be called using index and coloums with coloum names

# %%
df
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 0      AKHIL        1       10TH      90     89       86     99        95
# 1       ANIL        2       10TH      91     78       45     78        78
# 2      SUNNY        3       10TH      92     90       66     78        89
# 3     VISHWA        4       10TH      93     90       77     89        45
# 4     VAMSHI        5       10TH      97     98       87     88        56
# 5      SHIVA        6       10TH      85     77       98     56        67
# 6   SRINIVAS        7       10TH      86     55       90     76        89
# 7        RAJ        8       10TH      83     87       35     87        45
# 8       RAVI        9       10TH      90     55       56     54        66
# 9    PRAMODH       10       10TH      97     54       56     35        78
# 10    SHASHI       11       10TH      98     65       77     33        98
# 11       RAM       12       10TH      99     34       98     78        90
# ...

# %%
df.loc[1]
# Out:
# NAME          ANIL
# ROLL NO          2
# Unnamed: 2    10TH
# TELUGU          91
# HINDI           78
# ENGLISH         45
# MATHS           78
# SCIENCE         78
# SOCIAL          56
# Name: 1, dtype: object

# %%
df.loc[18]
# Out:
# NAME          SAIKUMAR
# ROLL NO             19
# Unnamed: 2       10TH
# TELUGU              53
# HINDI               55
# ENGLISH             54
# MATHS               77
# SCIENCE             78
# SOCIAL              70
# Name: 18, dtype: object

# %%
df.loc[0:5]
# Out:
#      NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   SOCIAL
# 0   AKHIL        1       10TH      90     89       86     99        95      92
# 1    ANIL        2       10TH      91     78       45     78        78      56
# 2   SUNNY        3       10TH      92     90       66     78        89      67
# 3  VISHWA        4       10TH      93     90       77     89        45      37
# 4  VAMSHI        5       10TH      97     98       87     88        56      87
# 5   SHIVA        6       10TH      85     77       98     56        67      88

# %%
df.loc[0,["NAME","TELUGU"]]
# Out:
# NAME      AKHIL
# TELUGU       90
# Name: 0, dtype: object

# %%
df.loc[0:5,["NAME"]]
# Out:
#      NAME
# 0   AKHIL
# 1    ANIL
# 2   SUNNY
# 3  VISHWA
# 4  VAMSHI
# 5   SHIVA

# %%
df.loc[0:4,"NAME":"SOCIAL"]
# Out:
#      NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   SOCIAL
# 0   AKHIL        1       10TH      90     89       86     99        95      92
# 1    ANIL        2       10TH      91     78       45     78        78      56
# 2   SUNNY        3       10TH      92     90       66     78        89      67
# 3  VISHWA        4       10TH      93     90       77     89        45      37
# 4  VAMSHI        5       10TH      97     98       87     88        56      87

# %% [markdown]
# ![pd5.jfif](attachment:pd5.jfif)

# %%
# HERE stopping index will be excluded and rows an coloums will be called with the index
df.iloc[0:4]
# Out:
#      NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   SOCIAL
# 0   AKHIL        1       10TH      90     89       86     99        95      92
# 1    ANIL        2       10TH      91     78       45     78        78      56
# 2   SUNNY        3       10TH      92     90       66     78        89      67
# 3  VISHWA        4       10TH      93     90       77     89        45      37

# %%
df.iloc[0,5]
# Out:
# 86

# %%
df.iloc[0,0]
# Out:
# 'AKHIL'

# %%
df.iloc[0:10,0:6]# df.iloc[row_start:row_end,coloum_start:coloum_end]
# Out:
#        NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH
# 0     AKHIL        1       10TH      90     89       86
# 1      ANIL        2       10TH      91     78       45
# 2     SUNNY        3       10TH      92     90       66
# 3    VISHWA        4       10TH      93     90       77
# 4    VAMSHI        5       10TH      97     98       87
# 5     SHIVA        6       10TH      85     77       98
# 6  SRINIVAS        7       10TH      86     55       90
# 7       RAJ        8       10TH      83     87       35
# 8      RAVI        9       10TH      90     55       56
# 9   PRAMODH       10       10TH      97     54       56

# %%
df.iloc[0:5,0]
# Out:
# 0     AKHIL
# 1      ANIL
# 2     SUNNY
# 3    VISHWA
# 4    VAMSHI
# Name: NAME, dtype: object

# %%
df.iloc[[1,5,8,9]]
# Out:
#       NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 1     ANIL        2       10TH      91     78       45     78        78
# 5    SHIVA        6       10TH      85     77       98     56        67
# 8     RAVI        9       10TH      90     55       56     54        66
# 9  PRAMODH       10       10TH      97     54       56     35        78
#
#    SOCIAL
# 1      56
# 5      88
# 8      89
# 9      45

# %%
df.iloc[:,[1,3,4,6]]
# Out:
#     ROLL NO  TELUGU  HINDI  MATHS
# 0         1      90     89     99
# 1         2      91     78     78
# 2         3      92     90     78
# 3         4      93     90     89
# 4         5      97     98     88
# 5         6      85     77     56
# 6         7      86     55     76
# 7         8      83     87     87
# 8         9      90     55     54
# 9        10      97     54     35
# 10       11      98     65     33
# 11       12      99     34     78
# 12       13      55     34     98
# 13       14      90     45     76
# 14       15      76     45     66
# 15       16      78     77     56
# 16       17      78     89     78
# 17       18      89     56     35
# 18       19      53     55     77

# %%
df.iloc[0:4,[1,3,5]]
# Out:
#    ROLL NO  TELUGU  ENGLISH
# 0        1      90       86
# 1        2      91       45
# 2        3      92       66
# 3        4      93       77

# %% [markdown]
# #   SORTING
# #  DATAFRAME

# %% [markdown]
# ![pd6.jfif](attachment:pd6.jfif)

# %%
df
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 0      AKHIL        1       10TH      90     89       86     99        95
# 1       ANIL        2       10TH      91     78       45     78        78
# 2      SUNNY        3       10TH      92     90       66     78        89
# 3     VISHWA        4       10TH      93     90       77     89        45
# 4     VAMSHI        5       10TH      97     98       87     88        56
# 5      SHIVA        6       10TH      85     77       98     56        67
# 6   SRINIVAS        7       10TH      86     55       90     76        89
# 7        RAJ        8       10TH      83     87       35     87        45
# 8       RAVI        9       10TH      90     55       56     54        66
# 9    PRAMODH       10       10TH      97     54       56     35        78
# 10    SHASHI       11       10TH      98     65       77     33        98
# 11       RAM       12       10TH      99     34       98     78        90
# ...

# %%
df.sort_values("TELUGU")
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 18  SAIKUMAR       19      10TH       53     55       54     77        78
# 12    ROHITH       13      10TH       55     34       45     98        89
# 14      RAJI       15      10TH       76     45       45     66        98
# 16     VIJAY       17      10TH       78     89       89     78        47
# 15      AJAY       16      10TH       78     77       90     56        56
# 7        RAJ        8       10TH      83     87       35     87        45
# 5      SHIVA        6       10TH      85     77       98     56        67
# 6   SRINIVAS        7       10TH      86     55       90     76        89
# 17    BABBLU       18      10TH       89     56       77     35        74
# 13     RAHUL       14      10TH       90     45       33     76        89
# 0      AKHIL        1       10TH      90     89       86     99        95
# 8       RAVI        9       10TH      90     55       56     54        66
# ...

# %%
df.sort_values("MATHS",ascending=False)
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 0      AKHIL        1       10TH      90     89       86     99        95
# 12    ROHITH       13      10TH       55     34       45     98        89
# 3     VISHWA        4       10TH      93     90       77     89        45
# 4     VAMSHI        5       10TH      97     98       87     88        56
# 7        RAJ        8       10TH      83     87       35     87        45
# 1       ANIL        2       10TH      91     78       45     78        78
# 2      SUNNY        3       10TH      92     90       66     78        89
# 16     VIJAY       17      10TH       78     89       89     78        47
# 11       RAM       12       10TH      99     34       98     78        90
# 18  SAIKUMAR       19      10TH       53     55       54     77        78
# 6   SRINIVAS        7       10TH      86     55       90     76        89
# 13     RAHUL       14      10TH       90     45       33     76        89
# ...

# %%
df.sort_values(["NAME",'TELUGU'])# SORT WILL DONE DEPENDING UPON THE FIRST COLOUM GIVEN
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 15      AJAY       16      10TH       78     77       90     56        56
# 0      AKHIL        1       10TH      90     89       86     99        95
# 1       ANIL        2       10TH      91     78       45     78        78
# 17    BABBLU       18      10TH       89     56       77     35        74
# 9    PRAMODH       10       10TH      97     54       56     35        78
# 13     RAHUL       14      10TH       90     45       33     76        89
# 7        RAJ        8       10TH      83     87       35     87        45
# 14      RAJI       15      10TH       76     45       45     66        98
# 11       RAM       12       10TH      99     34       98     78        90
# 8       RAVI        9       10TH      90     55       56     54        66
# 12    ROHITH       13      10TH       55     34       45     98        89
# 18  SAIKUMAR       19      10TH       53     55       54     77        78
# ...

# %% [markdown]
# ![pd7.jfif](attachment:pd7.jfif)

# %%
df["total"]=0 # ADDING A COLUM

# %%
df
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 0      AKHIL        1       10TH      90     89       86     99        95
# 1       ANIL        2       10TH      91     78       45     78        78
# 2      SUNNY        3       10TH      92     90       66     78        89
# 3     VISHWA        4       10TH      93     90       77     89        45
# 4     VAMSHI        5       10TH      97     98       87     88        56
# 5      SHIVA        6       10TH      85     77       98     56        67
# 6   SRINIVAS        7       10TH      86     55       90     76        89
# 7        RAJ        8       10TH      83     87       35     87        45
# 8       RAVI        9       10TH      90     55       56     54        66
# 9    PRAMODH       10       10TH      97     54       56     35        78
# 10    SHASHI       11       10TH      98     65       77     33        98
# 11       RAM       12       10TH      99     34       98     78        90
# ...

# %%
df["perc"]="pass/False"

# %%
df
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 0      AKHIL        1       10TH      90     89       86     99        95
# 1       ANIL        2       10TH      91     78       45     78        78
# 2      SUNNY        3       10TH      92     90       66     78        89
# 3     VISHWA        4       10TH      93     90       77     89        45
# 4     VAMSHI        5       10TH      97     98       87     88        56
# 5      SHIVA        6       10TH      85     77       98     56        67
# 6   SRINIVAS        7       10TH      86     55       90     76        89
# 7        RAJ        8       10TH      83     87       35     87        45
# 8       RAVI        9       10TH      90     55       56     54        66
# 9    PRAMODH       10       10TH      97     54       56     35        78
# 10    SHASHI       11       10TH      98     65       77     33        98
# 11       RAM       12       10TH      99     34       98     78        90
# ...

# %% [markdown]
# # removing duplicates

# %%
import pandas as pd

# %%
d =pd.read_excel("C:\\Users\\user\\Downloads\\student marks.xlsx")
df=pd.DataFrame(d)

# %%
df
# Out:
#         NAME  ROLL NO Unnamed: 2  TELUGU  HINDI  ENGLISH  MATHS  SCIENCE   \
# 0      AKHIL        1       10TH      90     89       86     99        95
# 1       ANIL        2       10TH      91     78       45     78        78
# 2      SUNNY        3       10TH      92     90       66     78        89
# 3     VISHWA        4       10TH      93     90       77     89        45
# 4     VAMSHI        5       10TH      97     98       87     88        56
# 5      SHIVA        6       10TH      85     77       98     56        67
# 6   SRINIVAS        7       10TH      86     55       90     76        89
# 7        RAJ        8       10TH      83     87       35     87        45
# 8       RAVI        9       10TH      90     55       56     54        66
# 9    PRAMODH       10       10TH      97     54       56     35        78
# 10    SHASHI       11       10TH      98     65       77     33        98
# 11       RAM       12       10TH      99     34       98     78        90
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# dtype: bool
